# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
data = pd.read_csv('D:\\Pyenv\\Submit\\University_Admission_Predication\\Dataset\\Admission_Predict.csv')

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
data.isnull().any()
# Out:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
data = data.rename(columns={'Chance of Admit ':'Chance of Admit'})
data = data.rename(columns={'LOR ':'LOR'})
data.drop(["Serial No."],axis=1,inplace=True)

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP         LOR  \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000       400.000000
# mean     8.598925    0.547500         0.724350
# std      0.596317    0.498362         0.142609
# min      6.800000    0.000000         0.340000
# 25%      8.170000    0.000000         0.640000
# 50%      8.610000    1.000000         0.730000
# 75%      9.062500    1.000000         0.830000
# max      9.920000    1.000000         0.970000

# %%
sns.displot(data['GRE Score'])

# %%
sns.pairplot(data=data,hue="Research",markers=["^","v"],palette="inferno")

# %%
sns.scatterplot(x="University Rating",y="CGPA",data=data,color="Red",s=100)
# Out:
# <AxesSubplot:xlabel='University Rating', ylabel='CGPA'>

# %%
category = ['GRE Score','TOEFL Score','University Rating','SOP','LOR','CGPA','Research','Chance of Admit']
color = ['yellowgreen','gold','lightskyblue','pink','red','purple','orange','gray']
start = True
for i in np.arange(4):
    fig = plt.figure(figsize=(14,8))
    plt.subplot2grid((4,2),(i,0))
    data[category[2*i]].hist(color=color[2*i],bins=10)
    plt.title(category[2*i])
    plt.subplot2grid((4,2),(i,1))
    data[category[2*i+1]].hist(color=color[2*i+1],bins=10)
    plt.title(category[2*i+1])
    
plt.subplots_adjust(hspace=0.7, wspace=0.2)
plt.show()

# %%
x=data.iloc[:,0:7].values
x
# Out:
# array([[337.  , 118.  ,   4.  , ...,   4.5 ,   9.65,   1.  ],
#        [324.  , 107.  ,   4.  , ...,   4.5 ,   8.87,   1.  ],
#        [316.  , 104.  ,   3.  , ...,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [330.  , 116.  ,   4.  , ...,   4.5 ,   9.45,   1.  ],
#        [312.  , 103.  ,   3.  , ...,   4.  ,   8.78,   0.  ],
#        [333.  , 117.  ,   4.  , ...,   4.  ,   9.66,   1.  ]])

# %%
y=data.iloc[:,7:].values
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
#        [0.36],
#        [0.42],
#        [0.48],
#        [0.47],
#        [0.54],
#        [0.56],
#        [0.52],
#        [0.55],
#        [0.61],
#        [0.57],
#        [0.68],
#        [0.78],
#        [0.94],
#        [0.96],
#        [0.93],
#        [0.84],
#        [0.74],
#        [0.72],
#        [0.74],
#        [0.64],
#        [0.44],
#        [0.46],
#        [0.5 ],
#        [0.96],
#        [0.92],
#        [0.92],
#        [0.94],
#        [0.76],
#        [0.72],
#        [0.66],
#        [0.64],
#        [0.74],
#        [0.64],
#        [0.38],
#        [0.34],
#        [0.44],
#        [0.36],
#        [0.42],
#        [0.48],
#        [0.86],
#        [0.9 ],
#        [0.79],
#        [0.71],
#        [0.64],
#        [0.62],
#        [0.57],
#        [0.74],
#        [0.69],
#        [0.87],
#        [0.91],
#        [0.93],
#        [0.68],
#        [0.61],
#        [0.69],
#        [0.62],
#        [0.72],
#        [0.59],
#        [0.66],
#        [0.56],
#        [0.45],
#        [0.47],
#        [0.71],
#        [0.94],
#        [0.94],
#        [0.57],
#        [0.61],
#        [0.57],
#        [0.64],
#        [0.85],
#        [0.78],
#        [0.84],
#        [0.92],
#        [0.96],
#        [0.77],
#        [0.71],
#        [0.79],
#        [0.89],
#        [0.82],
#        [0.76],
#        [0.71],
#        [0.8 ],
#        [0.78],
#        [0.84],
#        [0.9 ],
#        [0.92],
#        [0.97],
#        [0.8 ],
#        [0.81],
#        [0.75],
#        [0.83],
#        [0.96],
#        [0.79],
#        [0.93],
#        [0.94],
#        [0.86],
#        [0.79],
#        [0.8 ],
#        [0.77],
#        [0.7 ],
#        [0.65],
#        [0.61],
#        [0.52],
#        [0.57],
#        [0.53],
#        [0.67],
#        [0.68],
#        [0.81],
#        [0.78],
#        [0.65],
#        [0.64],
#        [0.64],
#        [0.65],
#        [0.68],
#        [0.89],
#        [0.86],
#        [0.89],
#        [0.87],
#        [0.85],
#        [0.9 ],
#        [0.82],
#        [0.72],
#        [0.73],
#        [0.71],
#        [0.71],
#        [0.68],
#        [0.75],
#        [0.72],
#        [0.89],
#        [0.84],
#        [0.93],
#        [0.93],
#        [0.88],
#        [0.9 ],
#        [0.87],
#        [0.86],
#        [0.94],
#        [0.77],
#        [0.78],
#        [0.73],
#        [0.73],
#        [0.7 ],
#        [0.72],
#        [0.73],
#        [0.72],
#        [0.97],
#        [0.97],
#        [0.69],
#        [0.57],
#        [0.63],
#        [0.66],
#        [0.64],
#        [0.68],
#        [0.79],
#        [0.82],
#        [0.95],
#        [0.96],
#        [0.94],
#        [0.93],
#        [0.91],
#        [0.85],
#        [0.84],
#        [0.74],
#        [0.76],
#        [0.75],
#        [0.76],
#        [0.71],
#        [0.67],
#        [0.61],
#        [0.63],
#        [0.64],
#        [0.71],
#        [0.82],
#        [0.73],
#        [0.74],
#        [0.69],
#        [0.64],
#        [0.91],
#        [0.88],
#        [0.85],
#        [0.86],
#        [0.7 ],
#        [0.59],
#        [0.6 ],
#        [0.65],
#        [0.7 ],
#        [0.76],
#        [0.63],
#        [0.81],
#        [0.72],
#        [0.71],
#        [0.8 ],
#        [0.77],
#        [0.74],
#        [0.7 ],
#        [0.71],
#        [0.93],
#        [0.85],
#        [0.79],
#        [0.76],
#        [0.78],
#        [0.77],
#        [0.9 ],
#        [0.87],
#        [0.71],
#        [0.7 ],
#        [0.7 ],
#        [0.75],
#        [0.71],
#        [0.72],
#        [0.73],
#        [0.83],
#        [0.77],
#        [0.72],
#        [0.54],
#        [0.49],
#        [0.52],
#        [0.58],
#        [0.78],
#        [0.89],
#        [0.7 ],
#        [0.66],
#        [0.67],
#        [0.68],
#        [0.8 ],
#        [0.81],
#        [0.8 ],
#        [0.94],
#        [0.93],
#        [0.92],
#        [0.89],
#        [0.82],
#        [0.79],
#        [0.58],
#        [0.56],
#        [0.56],
#        [0.64],
#        [0.61],
#        [0.68],
#        [0.76],
#        [0.86],
#        [0.9 ],
#        [0.71],
#        [0.62],
#        [0.66],
#        [0.65],
#        [0.73],
#        [0.62],
#        [0.74],
#        [0.79],
#        [0.8 ],
#        [0.69],
#        [0.7 ],
#        [0.76],
#        [0.84],
#        [0.78],
#        [0.67],
#        [0.66],
#        [0.65],
#        [0.54],
#        [0.58],
#        [0.79],
#        [0.8 ],
#        [0.75],
#        [0.73],
#        [0.72],
#        [0.62],
#        [0.67],
#        [0.81],
#        [0.63],
#        [0.69],
#        [0.8 ],
#        [0.43],
#        [0.8 ],
#        [0.73],
#        [0.75],
#        [0.71],
#        [0.73],
#        [0.83],
#        [0.72],
#        [0.94],
#        [0.81],
#        [0.81],
#        [0.75],
#        [0.79],
#        [0.58],
#        [0.59],
#        [0.47],
#        [0.49],
#        [0.47],
#        [0.42],
#        [0.57],
#        [0.62],
#        [0.74],
#        [0.73],
#        [0.64],
#        [0.63],
#        [0.59],
#        [0.73],
#        [0.79],
#        [0.68],
#        [0.7 ],
#        [0.81],
#        [0.85],
#        [0.93],
#        [0.91],
#        [0.69],
#        [0.77],
#        [0.86],
#        [0.74],
#        [0.57],
#        [0.51],
#        [0.67],
#        [0.72],
#        [0.89],
#        [0.95],
#        [0.79],
#        [0.39],
#        [0.38],
#        [0.34],
#        [0.47],
#        [0.56],
#        [0.71],
#        [0.78],
#        [0.73],
#        [0.82],
#        [0.62],
#        [0.96],
#        [0.96],
#        [0.46],
#        [0.53],
#        [0.49],
#        [0.76],
#        [0.64],
#        [0.71],
#        [0.84],
#        [0.77],
#        [0.89],
#        [0.82],
#        [0.84],
#        [0.91],
#        [0.67],
#        [0.95]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=101)

y_train=(y_train>0.5)
y_test=(y_test>0.5)

# %%
from sklearn.linear_model import LogisticRegression
cls = LogisticRegression(random_state=0)
lr=cls.fit(x_train,y_train)
y_pred = lr.predict(x_test)
y_pred
# Out:
# C:\Users\sathya\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sathya\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
from sklearn.metrics import accuracy_score,recall_score,roc_auc_score,confusion_matrix
print("\nAccuracy score: %f" %(accuracy_score(y_test,y_pred)*100))
print("Recall score: %f" %(recall_score(y_test,y_pred)*100))
print("ROC score : %f\n" %(roc_auc_score(y_test,y_pred)*100))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score: 85.833333
# Recall score: 95.370370
# ROC score : 47.685185
#
# [[  0  12]
#  [  5 103]]

# %%
import pickle
pickle.dump(lr,open('university.pkl','wb'))
model=pickle.load(open('university.pkl','rb'))

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam

model = keras.Sequential()
model.add(Dense(7,activation="relu",input_dim=7))
model.add(Dense(7,activation="relu"))
model.add(Dense(1,activation="linear"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 7)                 56
#
#  dense_1 (Dense)             (None, 7)                 56
#
#  dense_2 (Dense)             (None, 1)                 8
#
# =================================================================
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer='adam',metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=20,epochs=100)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 5s 9ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 2/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 5/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 7/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 8/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 9/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 10/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 11/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 12/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 13/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 14/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 15/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 16/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 17/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 18/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 19/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 21/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 22/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 23/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 24/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 26/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 27/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 28/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 29/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 30/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 31/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 32/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 33/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 34/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 35/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 36/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 37/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 40/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 41/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 42/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 43/100
# 14/14 [==============================] - 0s 8ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 44/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 46/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 48/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 49/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 50/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 51/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 52/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 53/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 54/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 55/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 56/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 60/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 61/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 64/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 65/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 67/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 68/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 69/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 70/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 71/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 72/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 73/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 74/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 75/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 76/100
# 14/14 [==============================] - 0s 7ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 77/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 78/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 80/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 81/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 82/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 83/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 84/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 85/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 86/100
# 14/14 [==============================] - 0s 8ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 87/100
# 14/14 [==============================] - 0s 9ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 89/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 90/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 91/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 92/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 93/100
# 14/14 [==============================] - 0s 10ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 94/100
# 14/14 [==============================] - 0s 9ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 95/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 96/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 97/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 98/100
# 14/14 [==============================] - 0s 5ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 14.1579 - accuracy: 0.0821
# Epoch 100/100
# 14/14 [==============================] - 0s 8ms/step - loss: 14.1579 - accuracy: 0.0821
